# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishrdx/ML_to_GenAI_Journey/blob/main/Month_01_Foundations/Week_01_NumPy/Day_03_NumPy_Broadcasting_%26_Vectorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# How NumPy applies operations without loops — and why ML models depend on this.
#
# 1. Understand broadcasting rules clearly
#
# 2. Predict output shapes before running code
#
# 3. Write loop-free, ML-grade NumPy code
#
# 4. Avoid silent broadcasting bugs (very common)
