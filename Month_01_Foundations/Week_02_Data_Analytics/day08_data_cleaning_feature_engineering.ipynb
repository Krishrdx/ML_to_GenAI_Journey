# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishrdx/ML_to_GenAI_Journey/blob/main/Month_01_Foundations/Week_02_Data_Analytics/day08_data_cleaning_feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Missing values -
# Why missing data is dangerous?
#
# Models break
#
# Bias introduced
#
# Wrong gradients

# %% [markdown]
# ###why different strategies exist:
#
# Mean → numerical & symmetric
# Median → numerical & outliers present
# Mode → categorical

# %%
import pandas as pd
import numpy as np

# %%
df.isna().sum # Detect
df.dropna() #Remove
df.fillna(0) #Filling with constant
df.fillna(df.mean()) #Filling with mean

# %% [markdown]
# # The target / output that the model must learn to predict - LABEL
# Features (X) → Study Hours, Attendance
#
# Label (y) → Result (Pass / Fail)
# convert text → numbers
# This process = Encoding

# %% [markdown]
# Encoding Categorical Data
#
# - Label Encoding is OK for tree-based models
# - One-Hot is safer for linear / distance-based models

# %%
from sklearn.preprocessing import LabelEncoder  #introduces fake order, USE When categories ARE ordered (Low, Medium, High)
le = LabelEncoder()
df["city"]  = le.fit_transform(df["city"])

# %%
pd.get_dummies(df["city"])

#OHE - No fake order, Model treats all cities equally
#Downside? -> Too many columns (dimensionality explosion)

# %% [markdown]
# ### Feature Scaling (VERY IMPORTANT) ---> Tree models (Decision Tree, Random Forest) do NOT need scaling
# Why scaling?
#
# Faster convergence
#
# Stable gradients
#
# Distance-based models NEED it

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df[["age","salary"]]  = ss.fit_transform(df[["age","salary"]])

#(x - mean) / std
"""
Linear Regression
KNN
Decision Trees
Random Forest
Logistic Regression
Neural Networks
GenAI training

"""

# %% [markdown]
# Normalization (0 to 1)
#
# Formula:
# (x - min) / (max - min)
#
# Used when:
# Distance-based models,
# Images,
# KNN

# %% [markdown]
# Feature Creation

# %%
df["revenue"] = df["price"]*df["quantity"]
df["log_price"] = np.log(df["price"])

# %%
df["text_length"] = df["review"].str.len()

# %% [markdown]
# ###Test/train split
# If you train and test on same data:
# Model memorizes
#
# So we split:

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, Y_train,Y_test = train_test_split(X,Y,test_size=0.2, random_state = 42)

# %% [markdown]
# Why random_state?
#
# Reproducibility
#
# Debugging
#
# Fair comparison
