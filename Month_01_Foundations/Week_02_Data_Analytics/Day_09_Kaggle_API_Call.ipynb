# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishrdx/ML_to_GenAI_Journey/blob/main/Month_01_Foundations/Week_02_Data_Analytics/Day_09_Kaggle_API_Call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
KGAT_0e9a14fccf0837fb3ba2d70d71aed3d4

# %%
export KAGGLE_API_TOKEN=KGAT_0e9a14fccf0837fb3ba2d70d71aed3d4

# %%
kaggle competitions list
