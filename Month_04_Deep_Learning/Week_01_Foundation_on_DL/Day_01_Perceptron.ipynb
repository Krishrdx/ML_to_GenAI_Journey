# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishrdx/ML_to_GenAI_Journey/blob/main/Month_04_Deep_Learning/Week_01_Foundation_on_DL/Day_01_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['ouput']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      0
# 2       0       1      0
# 3       0       0      0

# %%
or_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
sns.scatterplot(or_data['input1'],or_data['input2'],hue=or_data['ouput'],s=200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2982796779.py in <cell line: 0>()
# ----> 1 sns.scatterplot(or_data['input1'],or_data['input2'],hue=or_data['ouput'],s=200)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
xor_data
# Out:
#    input1  input2  ouput
# 0       1       1      0
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
sns.scatterplot(
    data=xor_data,
    x='input1',
    y='input2',
    hue='output',
    s=200
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2532451921.py in <cell line: 0>()
# ----> 1 sns.scatterplot(
#       2     data=xor_data,
#       3     x='input1',
#       4     y='input2',
#       5     hue='output',
#
# /usr/local/lib/python3.12/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     613 ):
#     614
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.12/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     394         )
#     395
# --> 396         super().__init__(data=data, variables=variables)
#     397
#     398         self.legend = legend
#
# ...

# %% [markdown]
# Cell `ZVB9-dAS5Tao`:
# ```python
# sns.scatterplot(or_data['input1'],or_data['input2'],hue=or_data['ouput'],s=200)
# ```
# Error:
# ```
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
# ```

# %% [markdown]
# Cell `fQ9a1GiH5TUm`:
# ```python
# sns.scatterplot(
#     data=xor_data,
#     x='input1',
#     y='input2',
#     hue='output',
#     s=200
# )
# ```
# Error:
# ```
# ValueError: Could not interpret value `output` for `hue`. An entry with this name does not appear in `data`.
# ```

# %% [markdown]
# Cell `yc4JMxPI6ZAZ`:
# ```python
# plt.plot(x,y)
# sns.scatterplot(and_data['input1'],and_data['input2'],hue=and_data['ouput'],s=200)
# ```
# Error:
# ```
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
# ```

# %% [markdown]
# Cell `jE2rPItL6d6P`:
# ```python
# plt.plot(x1,y1)
# sns.scatterplot(or_data['input1'],or_data['input2'],hue=or_data['ouput'],s=200)
# ```
# Error:
# ```
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
# ```

# %% [markdown]
# Cell `QkAZbTgN6ogV`:
# ```python
# plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
# ```
# Error:
# ```
# NameError: name 'plot_decision_regions' is not defined
# ```

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(and_data['input1'],and_data['input2'],hue=and_data['ouput'],s=200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1052326130.py in <cell line: 0>()
#       1 plt.plot(x,y)
# ----> 2 sns.scatterplot(and_data['input1'],and_data['input2'],hue=and_data['ouput'],s=200)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(or_data['input1'],or_data['input2'],hue=or_data['ouput'],s=200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1604093968.py in <cell line: 0>()
#       1 plt.plot(x1,y1)
# ----> 2 sns.scatterplot(or_data['input1'],or_data['input2'],hue=or_data['ouput'],s=200)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-478289796.py in <cell line: 0>()
# ----> 1 plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
#
# NameError: name 'plot_decision_regions' is not defined
